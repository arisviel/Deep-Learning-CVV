# %%
import pandas as pd
import numpy as np

# %%
results = pd.read_csv('/content/drive/My Drive/Segmentation/results.csv')

# %%
np.nanmax(results['1 acc'].values)
# Out:
# 280080.001

# %%
np.nanmin(results['1 acc'].values)
# Out:
# 279207.963

# %%
np.nanmax(results['2 acc'].values)
# Out:
# 282087.6071

# %%
np.nanmax(results['3 acc'].values)
# Out:
# 281754.1643

# %%
np.nanmax(results['4 acc'].values)
# Out:
# 283779.47

# %%
np.nanmin(results['2 acc'].values)
# Out:
# 277297.1714

# %%
np.nanmin(results['3 acc'].values)
# Out:
# 276528.5786

# %%
np.nanmin(results['4 acc'].values)
# Out:
# 282740.123

# %%
276528.5786 92%

# %%
percent = 2860.680141129032

# %%
283779.47/99.2
# Out:
# 2860.680141129032

# %%
276528.5786/2860.680141129032
# Out:
# 96.66532606153645

# %%
np.round((best_acc), 2)

# %%
results['1 acc'] = results['1 acc']/percent

# %%
results['4 acc'] = results['4 acc']/percent

# %%
result = results

# %%
from matplotlib import pyplot as plt

# %%
fig, axs = plt.subplots(1, 2, figsize=(20,7))
#plt.subplots(figsize=(12,7))
axs[0].plot(result['1 loss'], '-', label='BCE loss + sigmoid layers')
axs[0].plot(result['2 loss'], '-', label='BCE WithlogistLoss')
axs[0].plot(result['3 loss'], '-', label='BCE WithlogistLoss lr 1e-5')
axs[0].plot(result['4 loss'], '-', label='BCE WithlogistLoss, mask [0-1]')
axs[1].plot(result['1 acc'], '-', label='BCE loss + sigmoid layers')
axs[1].plot(result['2 acc'], '-', label='BCE WithlogistLoss')
axs[1].plot(result['3 acc'], '-', label='BCE WithlogistLoss lr 1e-5')
axs[1].plot(result['4 acc'], '-', label='BCE WithlogistLoss, mask [0-1]')
#plt.title('Results')
axs[0].set_ylabel('Loss')
axs[0].set_xlabel('Epochs')
axs[0].legend()
axs[0].set_xlim(0,49)
axs[0].set_ylim(0,0.5)
axs[1].set_ylabel('Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_xlim(0,49)
axs[1].set_ylim(96,100)
axs[1].legend()
plt.show()
